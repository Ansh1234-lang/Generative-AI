# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
print(ps.stem("running"))
# Out:
# run

# %% [markdown]
# ### Stemming
# Stemming is the process of reducing a word to its word stem that afflixes to suffixes and prefixes to the roots of words known as lemma. Stemming is important in natural language understanding (NLU) and natural language processing(NLP).

# %%
# classification problem
#  comments of product is a positive or negative review
# review -----> eating, eat, eaten  [going, gone, gone]

words = ["eating","eat","goes","go","writes","programming","program","history","finally","finalize"]

# %% [markdown]
# ### PORTER STEMMER

# %%
# porter stemmer
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word+"------>"+stemming.stem(word))
# Out:
# eating------>eat
# eat------>eat
# goes------>goe
# go------>go
# writes------>write
# programming------>program
# program------>program
# history------>histori
# finally------>final
# finalize------>final

# %%
stemming.stem('congractulation')
# Out:
# 'congractul'

# %%
stemming.stem('sitting')
# Out:
# 'sit'

# %% [markdown]
# ### RegexpStemmer

# %% [markdown]
# NLTK has regexpStemmer clas  with the help of which we can easily implement regular Expression Stemmer algorithm. It basically takes a single regular expression and remove any prefic or suffix that matches the expression . Let us see an example.

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

reg_stemmer.stem("steps")
# Out:
# 'step'

# %%
reg_stemmer.stem('integrating')
# Out:
# 'integrat'

# %% [markdown]
# ###  Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

snowballStemmer=SnowballStemmer('english')

# %%
for word in words:
    print(word+"----->"+snowballStemmer.stem(word))
# Out:
# eating----->eat
# eat----->eat
# goes----->goe
# go----->go
# writes----->write
# programming----->program
# program----->program
# history----->histori
# finally----->final
# finalize----->final

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballStemmer.stem("sleeping"), snowballStemmer.stem("sportingly")
# Out:
# ('sleep', 'sport')
